# %% [markdown]
# 1. Introduction
#     * 1.1  Problem definition
#     * 1.2  Datasets
# 2. Environment
#     * 2.1  Packages
#     * 2.2  Parameters
#     * 2.3  Functions
#     * 2.4  Data
# 3. Wrangling
#     * 3.1  Typecasting
#     * 3.2  Renaming
#     * 3.3  Sorting
# 4. Conclusion
#     * 4.1  Results
#     * 4.2  Next steps

# %% [markdown]
# ## 2. Environment

# %% [markdown]
# ### 2.1 Packages

# %%
import os
import pandas as pd
import numpy as np

# own utils
from data_eng_utils import calc_df_size

# printing
from beeprint import pp
import pprint

# %% [markdown]
# ### 2.2 Parameters

# %%
# https://stackoverflow.com/questions/3207219/how-do-i-list-all-files-of-a-directory
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Aggregated_Metrics_By_Country_And_Subscriber_Status.csv',
#  'Aggregated_Metrics_By_Video.csv',
#  'All_Comments_Final.csv',
#  'data_eng_utils.py',
#  'kengee_youtube_data.ipynb',
#  'Video_Performance_Over_Time.csv',
#  '__pycache__']

# %%
ROOT_DIR = './'

COUNTRY_SUB_METRICS = 'Aggregated_Metrics_By_Country_And_Subscriber_Status.csv'
VIDEO_METRICS = 'Aggregated_Metrics_By_Video.csv'
ALL_COMMENTS = 'All_Comments_Final.csv'
VIDEO_PERFORMANCE = 'Video_Performance_Over_Time.csv'

# %% [markdown]
# ### 2.4 Data

# %% [markdown]
# Checking initial memory consumption prior to cleaning

# %%
# Reading data
country_metrics = pd.read_csv(COUNTRY_SUB_METRICS, encoding='utf-8')
video_metrics = pd.read_csv(VIDEO_METRICS, encoding='utf-8')
comments = pd.read_csv(ALL_COMMENTS, encoding='utf-8')
video_performance = pd.read_csv(VIDEO_PERFORMANCE, encoding='utf-8')

# %%
def calc_df_size(*args):
    tot_size = 0
    for df in args:
        tot_size += df.memory_usage().sum()
    return tot_size/1000000

# %%
size = calc_df_size(country_metrics, video_metrics, comments, video_performance)
print(f'Size is {size} MB')
# Out:
# Size is 19.38398 MB

# %% [markdown]
# ## 3. Wrangling
# - process of transforming and mapping data from one "raw" data form into another format with the intent of making it more appropriate and valuable for a variety of downstream purposes such as analytics.

# %%
# Analyis of country_metrics 
country_metrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55292 entries, 0 to 55291
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Video Title                 55292 non-null  object
#  1   External Video ID           55292 non-null  object
#  2   Video Length                55292 non-null  int64
#  3   Thumbnail link              55292 non-null  object
#  4   Country Code                54906 non-null  object
#  5   Is Subscribed               55292 non-null  bool
#  6   Views                       55292 non-null  int64
#  7   Video Likes Added           55292 non-null  int64
#  8   Video Dislikes Added        55292 non-null  int64
#  9   Video Likes Removed         55292 non-null  int64
#  10  User Subscriptions Added    55292 non-null  int64
#  11  User Subscriptions Removed  55292 non-null  int64
#  12  Average View Percentage     53854 non-null  float64
#  13  Average Watch Time          53854 non-null  float64
#  14  User Comments Added         55292 non-null  int64
# dtypes: bool(1), float64(2), int64(8), object(4)
# memory usage: 6.0+ MB

# %%
country_metrics.head(2)
# Out:
#                                          Video Title External Video ID  \
# 0  🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 1  🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
#
#    Video Length                                    Thumbnail link  \
# 0            59  https://i.ytimg.com/vi/OtqQYqRNDGI/hqdefault.jpg
# 1            59  https://i.ytimg.com/vi/OtqQYqRNDGI/hqdefault.jpg
#
#   Country Code  Is Subscribed  Views  Video Likes Added  Video Dislikes Added  \
# 0           HK           True     23                  1                     0
# 1           ME           True      3                  0                     0
#
#    Video Likes Removed  User Subscriptions Added  User Subscriptions Removed  \
# 0                    0                         2                           0
# 1                    0                         0                           0
#
#    Average View Percentage  Average Watch Time  User Comments Added
# 0                  0.67187           39.640348                    0
# 1                  0.49887           29.433333                    0

# %%
COUNTRY_METRICS_SCHEMA = {
    "Video Title": {
        "title": "title",
        "data_type": str
    },
    "External Video ID": {
        "title": "video_id",
        "data_type": str
    },
    "Video Length": {
        "title": "length_sec",
        "data_type": int
    },
    "Thumbnail link": {
        "title": "thumbnail",
        "data_type": str
    },
    "Country Code": {
        "title": "coutry",
        "data_type": str
    },
    "Is Subscribed": {
        "title": "subscribed",
        "data_type": bool
    },
    "Views": {
        "title": "views",
        "data_type": int
    },
    "Video Likes Added": {
        "title": "likes_added",
        "data_type": int
    },
    "Video Dislikes Added": {
        "title": "dislikes_added",
        "data_type": int
    },
    "Video Likes Removed": {
        "title": "likes_removed",
        "data_type": int
    },
    "User Subscriptions Added": {
        "title": "subscription_added",
        "data_type": int
    },
    "User Subscriptions Removed": {
        "title": "subscription_removed",
        "data_type": int
    },
    "Average View Percentage": {
        "title": "avg_views_percent",
        "data_type": float
    },
    "Average Watch Time": {
        "title": "avg_watch_time",
        "data_type": float
    },
    "User Comments Added": {
        "title": "comments",
        "data_type": int
    }
}

# %%
def schema_output(df):
    for col in df.columns:
        print(f'"{col}":', '{')
        print("\t\"title\": \"\",")
        print("\t\"data_type\": \"\"")
        print("}", end='')
        if df.columns[len(df.columns) - 1] != col:
            print(',', end='')
        print()

# %%
# Analysis of comments
comments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10240 entries, 0 to 10239
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Comments     10239 non-null  object
#  1   Comment_ID   10240 non-null  object
#  2   Reply_Count  10240 non-null  int64
#  3   Like_Count   10240 non-null  int64
#  4   Date         10240 non-null  object
#  5   VidId        10240 non-null  object
#  6   user_ID      10240 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 560.1+ KB

# %%
comments.head(2)
# Out:
#                                             Comments  \
# 0  Thanks for this video Ken.\n\nI decided to go ...
# 1  Hello ken jee!!! I'm doing a graduation on Com...
#
#                    Comment_ID  Reply_Count  Like_Count                  Date  \
# 0  UgxFZTIzC4UPyhhX_PZ4AaABAg            0           0  2022-01-22T08:13:29Z
# 1  Ugx3IYuAufhb932GYQx4AaABAg            0           0  2022-01-22T01:09:46Z
#
#          VidId   user_ID
# 0  xpIFS6jZbe8  user_981
# 1  xpIFS6jZbe8  user_213

# %%
COMMENTS_SCHEMA = {
    "Comments": {
        "title": "comment",
        "data_type": str
    },
    "Comment_ID": {
        "title": "comment_id",
        "data_type": str
    },
    "Reply_Count": {
        "title": "reply_count",
        "data_type": int
    },
    "Like_Count": {
        "title": "like_count",
        "data_type": int
    },
    "Date": {
        "title": "date",
        "data_type": "datetime"
    },
    "VidId": {
        "title": "video_id",
        "data_type": str
    },
    "user_ID": {
        "title": "user_id",
        "data_type": str
    }
}

# %%
# Analysis of Video Performance
video_performance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111857 entries, 0 to 111856
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Date                        111857 non-null  object
#  1   Video Title                 111857 non-null  object
#  2   External Video ID           111857 non-null  object
#  3   Video Length                111857 non-null  int64
#  4   Thumbnail link              111857 non-null  object
#  5   Views                       111857 non-null  int64
#  6   Video Likes Added           111857 non-null  int64
#  7   Video Dislikes Added        111857 non-null  int64
#  8   Video Likes Removed         111857 non-null  int64
#  9   User Subscriptions Added    111857 non-null  int64
#  10  User Subscriptions Removed  111857 non-null  int64
#  11  Average View Percentage     110510 non-null  float64
#  12  Average Watch Time          110510 non-null  float64
#  13  User Comments Added         111857 non-null  int64
# dtypes: float64(2), int64(8), object(4)
# memory usage: 11.9+ MB

# %%
video_performance.head(2)
# Out:
#           Date                                        Video Title  \
# 0  19 Jan 2022  Kaggle Project From Scratch - Part 2 (Explorat...
# 1  19 Jan 2022     Welcome To My Channel | Ken Jee | Data Science
#
#   External Video ID  Video Length  \
# 0       KQ80oD_boBM          2191
# 1       smeFkHwnM_k            51
#
#                                      Thumbnail link  Views  Video Likes Added  \
# 0  https://i.ytimg.com/vi/KQ80oD_boBM/hqdefault.jpg     13                  0
# 1  https://i.ytimg.com/vi/smeFkHwnM_k/hqdefault.jpg      2                  0
#
#    Video Dislikes Added  Video Likes Removed  User Subscriptions Added  \
# 0                     0                    0                         0
# 1                     0                    0                         1
#
#    User Subscriptions Removed  Average View Percentage  Average Watch Time  \
# 0                           0                 0.069055          151.300154
# 1                           0                 0.471255           24.034000
#
#    User Comments Added
# 0                    0
# 1                    0

# %%
VIDEO_PERFORMANCE_SCHEMA = {
    "Date": {
        "title": "date",
        "data_type": "datetime"
    },
    "Video Title": {
        "title": "title",
        "data_type": str
    },
    "External Video ID": {
        "title": "video_id",
        "data_type": str
    },
    "Video Length": {
        "title": "length_sec",
        "data_type": int
    },
    "Thumbnail link": {
        "title": "thumbnail",
        "data_type": str
    },
    "Views": {
        "title": "views",
        "data_type": int
    },
    "Video Likes Added": {
        "title": "likes_added",
        "data_type": int
    },
    "Video Dislikes Added": {
        "title": "dislikes_added",
        "data_type": int
    },
    "Video Likes Removed": {
        "title": "likes_removed",
        "data_type": int
    },
    "User Subscriptions Added": {
        "title": "subscribers_added",
        "data_type": int
    },
    "User Subscriptions Removed": {
        "title": "subscribers_removed",
        "data_type": int
    },
    "Average View Percentage": {
        "title": "avg_views_percent",
        "data_type": float
    },
    "Average Watch Time": {
        "title": "avg_watch_time",
        "data_type": float
    },
    "User Comments Added": {
        "title": "comments",
        "data_type": int
    }
}

# %%
# Analysis of video metrics
video_metrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224 entries, 0 to 223
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Video                                 224 non-null    object
#  1   Video title                           223 non-null    object
#  2   Video pub­lish time                   223 non-null    object
#  3   Com­ments ad­ded                      224 non-null    int64
#  4   Shares                                224 non-null    int64
#  5   Dis­likes                             224 non-null    int64
#  6   Likes                                 224 non-null    int64
#  7   Sub­scribers lost                     224 non-null    int64
#  8   Sub­scribers gained                   224 non-null    int64
#  9   RPM (USD)                             224 non-null    float64
#  10  CPM (USD)                             222 non-null    float64
#  11  Av­er­age per­cent­age viewed (%)     224 non-null    float64
#  12  Av­er­age view dur­a­tion             224 non-null    object
#  13  Views                                 224 non-null    int64
#  14  Watch time (hours)                    224 non-null    float64
#  15  Sub­scribers                          224 non-null    int64
#  16  Your es­tim­ated rev­en­ue (USD)      224 non-null    float64
#  17  Im­pres­sions                         224 non-null    int64
#  18  Im­pres­sions click-through rate (%)  224 non-null    float64
# dtypes: float64(6), int64(9), object(4)
# memory usage: 33.4+ KB

# %%
video_metrics.head(2)
# Out:
#          Video                                        Video title  \
# 0        Total                                                NaN
# 1  4OZip0cgOho  How I Would Learn Data Science (If I Had to St...
#
#   Video pub­lish time  Com­ments ad­ded  Shares  Dis­likes   Likes  \
# 0                 NaN             14197   39640       3902  225021
# 1         May 8, 2020               907    9583        942   46903
#
#    Sub­scribers lost  Sub­scribers gained  RPM (USD)  CPM (USD)  \
# 0              45790               229241      5.276     11.990
# 1                451                46904      6.353     12.835
#
#    Av­er­age per­cent­age viewed (%) Av­er­age view dur­a­tion    Views  \
# 0                              26.61                   0:03:25  5568487
# 1                              36.65                   0:03:09  1253559
#
#    Watch time (hours)  Sub­scribers  Your es­tim­ated rev­en­ue (USD)  \
# 0         317602.3536        183451                         29068.652
# 1          65850.7042         46453                          7959.533
#
#    Im­pres­sions  Im­pres­sions click-through rate (%)
# 0      100954064                                  3.16
# 1       26498799                                  3.14

# %%
VIDEO_METRICS_SCHEMA = {
    "Video": {
        "title": "video_id",
        "data_type": str
    },
    "Video title": {
        "title": "title",
        "data_type": str
    },
    "Video publish time": {
        "title": "publish_time",
        "data_type": "datetime"
    },
    "Comments added": {
        "title": "comments_added",
        "data_type": int
    },
    "Shares": {
        "title": "shares",
        "data_type": int
    },
    "Dislikes": {
        "title": "dislikes",
        "data_type": int
    },
    "Likes": {
        "title": "likes",
        "data_type": int
    },
    "Subscribers lost": {
        "title": "subscribers_lost",
        "data_type": int
    },
    "Subscribers gained": {
        "title": "subscribers_gained",
        "data_type": int
    },
    "RPM (USD)": {
        "title": "revenue_per_1000_usd",
        "data_type": float
    },
    "CPM (USD)": {
        "title": "cost_per_1000_usd",
        "data_type": float
    },
    "Average percentage viewed (%)": {
        "title": "avg_percent_viewed",
        "data_type": float
    },
    "Average view duration": {
        "title": "avg_view_duration",
        "data_type": "timedelta"
    },
    "Views": {
        "title": "views",
        "data_type": int
    },
    "Watch time (hours)": {
        "title": "watch_time_hr",
        "data_type": float
    },
    "Subscribers": {
        "title": "subscribers",
        "data_type": int
    },
    "Your estimated revenue (USD)": {
        "title": "estimated_revenue",
        "data_type": float
    },
    "Impressions": {
        "title": "impressions",
        "data_type": int
    },
    "Impressions click-through rate (%)": {
        "title": "impression_click_rate",
        "data_type": float
    }
}

# %% [markdown]
# ### 3.1 Typecasting and 3.2 renaming data

# %%
'''
country_metrics = pd.read_csv(COUNTRY_SUB_METRICS)
video_metrics = pd.read_csv(VIDEO_METRICS)
comments = pd.read_csv(ALL_COMMENTS)
video_performance = pd.read_csv(VIDEO_PERFORMANCE)
'''
# Out:
# '\ncountry_metrics = pd.read_csv(COUNTRY_SUB_METRICS)\nvideo_metrics = pd.read_csv(VIDEO_METRICS)\ncomments = pd.read_csv(ALL_COMMENTS)\nvideo_performance = pd.read_csv(VIDEO_PERFORMANCE)\n'

# %%
# to time delta
# https://pandas.pydata.org/docs/reference/api/pandas.to_timedelta.html

def type_cast_column(col, schema):
    # search through schema to confirm title is present
    found_dtype = schema[col.name]
    if found_dtype == int:
        return col.astype(np.int32)
    elif found_dtype == float:
        return col.astype(np.float32)
    elif found_dtype == 'datetime':
        return pd.to_datetime(col)
    elif found_dtype == 'timedelta':
        # convert to timedelta seconds
        return pd.to_timedelta(col, unit='S')
    else:
        return col

# %%
def type_cast_df(df, schema):
    cpy = df.copy()
    # update column names as there are issues with unicode issues with title for video performance metrics
    new_col_names = [item['title'] for key, item in schema.items()]
    cpy.columns = new_col_names
    # create new dict from schema
    schema_upt = {item['title']:item['data_type'] for key, item in schema.items()}
    for col in cpy.columns:
        cpy[col] = type_cast_column(cpy[col], schema_upt)

    return cpy

# %%
video_performance_upt = type_cast_df(video_performance, VIDEO_PERFORMANCE_SCHEMA)
comments_upt = type_cast_df(comments, COMMENTS_SCHEMA)
country_metrics_upt = type_cast_df(country_metrics, COUNTRY_METRICS_SCHEMA)
video_metrics_upt = type_cast_df(video_metrics, VIDEO_METRICS_SCHEMA)

# %%
size_upt = calc_df_size(video_performance_upt, comments_upt, country_metrics_upt, video_metrics_upt)
print(f'Before: {size}, After: {size_upt}')
print(f'Decrease in size = {round((size - size_upt) / size * 100, 2)}')
# Out:
# Before: 19.38398, After: 12.60266
# Decrease in size = 34.98

# %% [markdown]
# ### 3.3 Sorting data

# %%
video_performance_upt.sort_values(by="date", inplace=True)
comments_upt.sort_values(by="date", inplace=True)
# country_metrics_upt.sort_values(by="date", inplace=True)
video_metrics_upt.sort_values(by='publish_time', inplace=True)

# %% [markdown]
# ## 4. Conclusion

# %% [markdown]
# ### 4.1 Observation of data

# %%
# video performance
video_performance_upt.describe(include='all')
# Out:
#                        date  \
# count                111857
# unique                 1523
# top     2021-10-04 00:00:00
# freq                    202
# first   2017-11-01 00:00:00
# last    2022-01-19 00:00:00
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN
#
#                                                     title     video_id  \
# count                                              111857       111857
# unique                                                223          223
# top     Predicting Crypto-Currency Price Using RNN lST...  qfRhKHV8-t4
# freq                                                 1522         1522
# first                                                 NaN          NaN
# last                                                  NaN          NaN
# mean                                                  NaN          NaN
# std                                                   NaN          NaN
# min                                                   NaN          NaN
# 25%                                                   NaN          NaN
# 50%                                                   NaN          NaN
# 75%                                                   NaN          NaN
# max                                                   NaN          NaN
#
#            length_sec                                         thumbnail  \
# count   111857.000000                                            111857
# unique            NaN                                               223
# top               NaN  https://i.ytimg.com/vi/qfRhKHV8-t4/hqdefault.jpg
# freq              NaN                                              1522
# first             NaN                                               NaN
# last              NaN                                               NaN
# mean       874.615876                                               NaN
# std        861.297667                                               NaN
# min         47.000000                                               NaN
# 25%        375.000000                                               NaN
# 50%        548.000000                                               NaN
# 75%        917.000000                                               NaN
# max       5029.000000                                               NaN
#
#                 views    likes_added  dislikes_added  likes_removed  \
# count   111857.000000  111857.000000   111857.000000  111857.000000
# unique            NaN            NaN             NaN            NaN
# top               NaN            NaN             NaN            NaN
# freq              NaN            NaN             NaN            NaN
# first             NaN            NaN             NaN            NaN
# last              NaN            NaN             NaN            NaN
# mean        49.714287       2.095533        0.052424       0.086789
# std        316.557515      14.263695        1.852013       1.793532
# min          0.000000       0.000000        0.000000       0.000000
# 25%          3.000000       0.000000        0.000000       0.000000
# 50%          9.000000       0.000000        0.000000       0.000000
# 75%         28.000000       1.000000        0.000000       0.000000
# max      35677.000000    1610.000000      289.000000     420.000000
#
#         subscribers_added  subscribers_removed  avg_views_percent  \
# count       111857.000000        111857.000000      110510.000000
# unique                NaN                  NaN                NaN
# top                   NaN                  NaN                NaN
# freq                  NaN                  NaN                NaN
# first                 NaN                  NaN                NaN
# last                  NaN                  NaN                NaN
# mean             1.169180             0.026391           0.350455
# std             12.109065             0.313908           0.232563
# min              0.000000             0.000000           0.000000
# 25%              0.000000             0.000000           0.178010
# 50%              0.000000             0.000000           0.336824
# 75%              0.000000             0.000000           0.476257
# max           1844.000000            32.000000           8.476339
#
#         avg_watch_time  comments
# count    110510.000000  111857.0
# unique             NaN       NaN
# top                NaN       NaN
# freq               NaN       NaN
# first              NaN       NaN
# last               NaN       NaN
# mean        216.766586       0.0
# std         190.707611       0.0
# min           0.000000       0.0
# 25%         117.379082       0.0
# 50%         181.505005       0.0
# 75%         268.126892       0.0
# max        5322.299805       0.0

# %%
# comments 
comments_upt.describe(include='all')
# Out:
#            comment                  comment_id   reply_count    like_count  \
# count        10239                       10240  10240.000000  10240.000000
# unique       10135                       10240           NaN           NaN
# top     I like it!  UgwPYqQkhITNHoyENH94AaABAg           NaN           NaN
# freq            12                           1           NaN           NaN
# first          NaN                         NaN           NaN           NaN
# last           NaN                         NaN           NaN           NaN
# mean           NaN                         NaN      1.337695      2.767578
# std            NaN                         NaN      1.096668     10.803318
# min            NaN                         NaN      0.000000      0.000000
# 25%            NaN                         NaN      1.000000      1.000000
# 50%            NaN                         NaN      1.000000      1.000000
# 75%            NaN                         NaN      2.000000      2.000000
# max            NaN                         NaN     21.000000    501.000000
#
#                              date     video_id    user_id
# count                       10240        10240      10240
# unique                      10238          222       5875
# top     2020-06-26 13:34:44+00:00  4OZip0cgOho  user_2385
# freq                            2          797        150
# first   2017-12-03 18:52:35+00:00          NaN        NaN
# last    2022-01-22 08:13:29+00:00          NaN        NaN
# mean                          NaN          NaN        NaN
# std                           NaN          NaN        NaN
# min                           NaN          NaN        NaN
# 25%                           NaN          NaN        NaN
# 50%                           NaN          NaN        NaN
# 75%                           NaN          NaN        NaN
# max                           NaN          NaN        NaN

# %%
# country metrics
country_metrics_upt.describe(include='all')
# Out:
#                                                     title     video_id  \
# count                                               55292        55292
# unique                                                223          223
# top     How I Would Learn Data Science (If I Had to St...  4OZip0cgOho
# freq                                                  428          428
# mean                                                  NaN          NaN
# std                                                   NaN          NaN
# min                                                   NaN          NaN
# 25%                                                   NaN          NaN
# 50%                                                   NaN          NaN
# 75%                                                   NaN          NaN
# max                                                   NaN          NaN
#
#           length_sec                                         thumbnail coutry  \
# count   55292.000000                                             55292  54906
# unique           NaN                                               223    233
# top              NaN  https://i.ytimg.com/vi/4OZip0cgOho/hqdefault.jpg     IN
# freq             NaN                                               428    445
# mean      896.678073                                               NaN    NaN
# std       927.380801                                               NaN    NaN
# min        47.000000                                               NaN    NaN
# 25%       375.000000                                               NaN    NaN
# 50%       545.000000                                               NaN    NaN
# 75%       934.000000                                               NaN    NaN
# max      5029.000000                                               NaN    NaN
#
#        subscribed          views   likes_added  dislikes_added  likes_removed  \
# count       55292   55292.000000  55292.000000    55292.000000   55292.000000
# unique          2            NaN           NaN             NaN            NaN
# top         False            NaN           NaN             NaN            NaN
# freq        28588            NaN           NaN             NaN            NaN
# mean          NaN     100.573157      4.239311        0.106055       0.175577
# std           NaN    1704.966002     65.291451        2.507351       3.601171
# min           NaN       0.000000      0.000000        0.000000       0.000000
# 25%           NaN       2.000000      0.000000        0.000000       0.000000
# 50%           NaN       7.000000      0.000000        0.000000       0.000000
# 75%           NaN      27.000000      1.000000        0.000000       0.000000
# max           NaN  285593.000000   9165.000000      399.000000     436.000000
#
#         subscription_added  subscription_removed  avg_views_percent  \
# count         55292.000000          55292.000000       53854.000000
# unique                 NaN                   NaN                NaN
# top                    NaN                   NaN                NaN
# freq                   NaN                   NaN                NaN
# mean              2.365279              0.053389           0.347821
# std              65.889539              0.766945           0.259732
# min               0.000000              0.000000           0.000000
# 25%               0.000000              0.000000           0.145948
# 50%               0.000000              0.000000           0.320983
# 75%               0.000000              0.000000           0.486153
# max            9599.000000            103.000000           4.967797
#
#         avg_watch_time  comments
# count     53854.000000   55292.0
# unique             NaN       NaN
# top                NaN       NaN
# freq               NaN       NaN
# mean        205.298340       0.0
# std         206.541626       0.0
# min           0.000000       0.0
# 25%          85.442894       0.0
# 50%         170.139725       0.0
# 75%         259.449951       0.0
# max        5027.660156       0.0

# %%
country_metrics_upt[country_metrics_upt['views'] == 285593.000000]
# Out:
#                                                    title     video_id  \
# 35823  How I Would Learn Data Science (If I Had to St...  4OZip0cgOho
#
#        length_sec                                         thumbnail coutry  \
# 35823         516  https://i.ytimg.com/vi/4OZip0cgOho/hqdefault.jpg     US
#
#        subscribed   views  likes_added  dislikes_added  likes_removed  \
# 35823       False  285593         9165             399            327
#
#        subscription_added  subscription_removed  avg_views_percent  \
# 35823                   0                     0           0.394064
#
#        avg_watch_time  comments
# 35823      203.337006         0

# %%
# video_metrics
video_metrics_upt.describe(include='all')
# Out:
#            video_id                                              title  \
# count           223                                                223
# unique          223                                                223
# top     hOUrxTeBJQc  Find a Data Science Project With These 3 Techn...
# freq              1                                                  1
# first           NaN                                                NaN
# last            NaN                                                NaN
# mean            NaN                                                NaN
# std             NaN                                                NaN
# min             NaN                                                NaN
# 25%             NaN                                                NaN
# 50%             NaN                                                NaN
# 75%             NaN                                                NaN
# max             NaN                                                NaN
#
#                publish_time  comments_added       shares    dislikes  \
# count                   223      223.000000   223.000000  223.000000
# unique                  222             NaN          NaN         NaN
# top     2019-03-03 00:00:00             NaN          NaN         NaN
# freq                      2             NaN          NaN         NaN
# first   2017-06-06 00:00:00             NaN          NaN         NaN
# last    2022-01-17 00:00:00             NaN          NaN         NaN
# mean                    NaN       63.654709   177.753363   17.497758
# std                     NaN       91.559620   733.331174   69.578517
# min                     NaN        0.000000     0.000000    0.000000
# 25%                     NaN       18.000000    19.000000    1.000000
# 50%                     NaN       37.000000    46.000000    4.000000
# 75%                     NaN       66.000000   112.500000   11.000000
# max                     NaN      907.000000  9583.000000  942.000000
#
#                likes  subscribers_lost  subscribers_gained  \
# count     223.000000        223.000000          223.000000
# unique           NaN               NaN                 NaN
# top              NaN               NaN                 NaN
# freq             NaN               NaN                 NaN
# first            NaN               NaN                 NaN
# last             NaN               NaN                 NaN
# mean     1008.865471         13.260090          587.309417
# std      3577.895609         33.242009         3302.316610
# min         1.000000          0.000000            0.000000
# 25%       163.000000          2.000000           27.000000
# 50%       342.000000          7.000000           68.000000
# 75%       713.000000         14.000000          234.500000
# max     46903.000000        451.000000        46904.000000
#
#         revenue_per_1000_usd  cost_per_1000_usd  avg_percent_viewed  \
# count             223.000000         221.000000          223.000000
# unique                   NaN                NaN                 NaN
# top                      NaN                NaN                 NaN
# freq                     NaN                NaN                 NaN
# first                    NaN                NaN                 NaN
# last                     NaN                NaN                 NaN
# mean                4.438302          11.440302           34.120804
# std                 1.792296           3.342146           15.144405
# min                 0.000000           5.439000            5.230000
# 25%                 3.219500           9.377000           23.515000
# 50%                 4.334000          11.160000           35.259998
# 75%                 5.382500          12.904000           43.484999
# max                10.387000          37.785999           76.599998
#
#              avg_view_duration         views  watch_time_hr   subscribers  \
# count                      223  2.230000e+02     223.000000    223.000000
# unique                     NaN           NaN            NaN           NaN
# top                        NaN           NaN            NaN           NaN
# freq                       NaN           NaN            NaN           NaN
# first                      NaN           NaN            NaN           NaN
# last                       NaN           NaN            NaN           NaN
# mean    0 days 00:03:20.659192  2.496860e+04    1424.201782    574.049327
# std     0 days 00:01:34.649236  8.960956e+04    4804.354004   3270.679889
# min            0 days 00:00:25  6.000000e+01       1.068400    -21.000000
# 25%     0 days 00:02:24.500000  3.933000e+03     176.995552     19.500000
# 50%            0 days 00:03:09  8.275000e+03     393.397308     62.000000
# 75%     0 days 00:04:01.500000  1.831800e+04    1128.712158    227.000000
# max            0 days 00:10:21  1.253559e+06   65850.703125  46453.000000
#
#         estimated_revenue   impressions  impression_click_rate
# count          223.000000  2.230000e+02             223.000000
# unique                NaN           NaN                    NaN
# top                   NaN           NaN                    NaN
# freq                  NaN           NaN                    NaN
# first                 NaN           NaN                    NaN
# last                  NaN           NaN                    NaN
# mean           130.348633  4.526904e+05               3.083812
# std            554.503662  1.864351e+06               1.674198
# min              0.000000  3.650000e+02               0.490000
# 25%             12.145500  9.894000e+04               1.920000
# 50%             32.537998  1.541870e+05               2.890000
# 75%             93.901501  2.799850e+05               3.980000
# max           7959.533203  2.649880e+07              11.510000

# %%
video_metrics_tot = video_metrics_upt.loc[0, :]
video_metrics_upt = video_metrics_upt.drop(0, axis=0).reset_index(drop=True)

# %% [markdown]
# ### 4.2 Wrap up
# 1. Video metrics's column titles include unicode characters which are not read properly by pandas
#     - function to update column data types considers only the updated titles from each individual dataframe's schema
# 2. Video metrics includes a row describing total of each column, the final total row is saved under the `video_metrics_tot` variable, and is dropped from our dataframe
# 3. There exists missing values in all of the data
